# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np

# %%
# Generate the x values from 0 to 10 using a step of 0.1
x_axis = np.arange(0, 10, 0.1)
sin = np.sin(x_axis)
cos = np.cos(x_axis)

plt.plot(x_axis,sin)
plt.plot(x_axis,cos)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Add a semi-transparent horizontal line at y = 0
plt.hlines(0,0,10,alpha=0.25)
plt.show()

# %%
# Use dots or other markers for your plots, and change their colors
sine_handle,=plt.plot(x_axis,sin,marker='o',color='blue',label="Sine")
cosine_handle,=plt.plot(x_axis,cos,marker='o',color='red',label="Cosine")

plt.legend(loc="upper right")
plt.show()

# %%
# Add labels to the x and y axes
plt.xlabel("numbers")
plt.ylabel("Sine and Cosine")
# Out:
# Text(0, 0.5, 'Sine and Cosine')

# %%
# Set your x and y limits
plt.xlim(0,10)
plt.ylim(-1,1)
# Out:
# (-1.0, 1.0)

# %%
# Set a grid on the plot
plt.grid()

# %%
# Save the plot and display it
plt.show()
