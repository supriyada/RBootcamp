# %%
# %matplotlib notebook

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
car_data = pd.read_csv('../Resources/mpg.csv')
car_data.head()
car_data=car_data.sort_values(['horsepower'],ascending=False)
car_data.head()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 354  34.5          4         100.0          ?    2320          15.8
# 374  23.0          4         151.0          ?    3035          20.5
# 126  21.0          6         200.0          ?    2875          17.0
# 330  40.9          4          85.0          ?    1835          17.3
# 32   25.0          4          98.0          ?    2046          19.0
#
#      model year  origin              car name
# 354          81       2           renault 18i
# 374          82       1        amc concord dl
# 126          74       1         ford maverick
# 330          80       2  renault lecar deluxe
# 32           71       1            ford pinto

# %%
# Remove the rows with missing values in horsepower
car_data = car_data.loc[car_data['horsepower'] != "?"]
car_data.count()
# Out:
# mpg             392
# cylinders       392
# displacement    392
# horsepower      392
# weight          392
# acceleration    392
# model year      392
# origin          392
# car name        392
# dtype: int64

# %%
# Set the 'car name' as our index
car_data = car_data.set_index("car name")

# Remove the 'origin' column
del car_data['origin']

car_data.head()
# Out:
#                   mpg  cylinders  displacement horsepower  weight  \
# car name
# volvo 244dl      22.0          4         121.0         98    2945
# ford granada     18.5          6         250.0         98    3525
# amc hornet       18.0          6         199.0         97    2774
# mazda rx2 coupe  19.0          3          70.0         97    2330
# datsun 810       22.0          6         146.0         97    2815
#
#                  acceleration  model year
# car name
# volvo 244dl              14.5          75
# ford granada             19.0          77
# amc hornet               15.5          70
# mazda rx2 coupe          13.5          72
# datsun 810               14.5          77

# %%
# Convert the "horsepower" column to numeric so the data can be used
car_data['horsepower'] = pd.to_numeric(car_data['horsepower'])

# %%
# Create a scatter plot which compares MPG to horsepower
car_scatter = car_data.plot(kind="scatter",x='horsepower',y='mpg',grid=True,title="MPG Vs Horsepower")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
