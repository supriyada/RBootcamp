# %%
# Create code to answer each of the following questions.
# Hint: You will need multiple target URLs and multiple API requests.

# Dependencies
import requests
import json

# Google API Key
from config import gkey

# %%
# 1. What are the geocoordinates (latitude and longitude) of Seattle,
# Washington?
target_city = "Seattle, Washington"

params = {"address": target_city, "key": gkey}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/geocode/json"

print("Drill #1: The Geocoordinates of Seattle, WA")

# Run request
response = requests.get(base_url, params = params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)

# Convert to JSON
seattle_geo = response.json()
seattle_geo
# Out:
# Drill #1: The Geocoordinates of Seattle, WA
# {'results': [{'address_components': [{'long_name': 'Seattle',
#      'short_name': 'Seattle',
#      'types': ['locality', 'political']},
#     {'long_name': 'King County',
#      'short_name': 'King County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Washington',
#      'short_name': 'WA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Seattle, WA, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 47.734145,
#       'lng': -122.2244331},
#      'southwest': {'lat': 47.4919119, 'lng': -122.4596959}},
#     'location': {'lat': 47.6062095, 'lng': -122.3320708},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 47.734145, 'lng': -122.2244331},
#      'southwest': {'lat': 47.4919119, 'lng': -122.4596959}}},
#    'place_id': 'ChIJVTPokywQkFQRmtVEaUZlJRA',
#    'types': ['locality', 'political']}],
#  'status': 'OK'}

# %%
# Extract lat/lng
lat = seattle_geo['results'][0]['geometry']['location']['lat']
lng = seattle_geo['results'][0]['geometry']['location']['lng']

# Print results
print(f"{target_city}: {lat}, {lng}")

#Drill #1
#Seattle, Washington: 47.6062095, -122.3320708
# Out:
# Seattle, Washington: 47.6062095, -122.3320708

# %%
# 2. What are the geocoordinates (latitude and longitude) of The White House?
# update params dict
target_city = "The White House"
params["address"] = target_city


print("Drill #2: The Geocoordinates of the White House")


# Run request
response = requests.get(base_url, params = params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)

dc_geo = response.json()
# Extract lat/lng
lat = dc_geo['results'][0]['geometry']['location']['lat']
lng = dc_geo['results'][0]['geometry']['location']['lng']

# Print results
print(f"{target_city}: {lat}, {lng}")
# Out:
# Drill #2: The Geocoordinates of the White House
# The White House: 38.8976763, -77.0365298

# %%
# 3. Find the name and address of a bike store in Seattle, Washington.
#    Hint: See https://developers.google.com/places/web-service/supported_types
target_type = "bicycle_store"
seattle_coords = "47.6062095,-122.3320708"
radius = 8000

# rewrite params dict

params = {
    "location": seattle_coords,
    "types": target_type,
    "radius": radius,
    "key": gkey
}

# Build URL using the Google Maps API
base_url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'

print("Drill #3: A Bike Store in Seattle, WA")

# Run request


# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)

seattle_bikes = requests.get(base_url, params = params)

seattle_bikes_j = seattle_bikes.json()
# Print the JSON (pretty printed)
print(json.dumps(seattle_bikes_j, indent=4, sort_keys=True))

# Print the name and address of the first bike shop to appear
# Out:
# Drill #3: A Bike Store in Seattle, WA
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6203442,
#                     "lng": -122.3297537
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6217418802915,
#                         "lng": -122.3287446197085
#                     },
#                     "southwest": {
#                         "lat": 47.6190439197085,
#                         "lng": -122.3314425802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "REI",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1536,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116079265035738039892\">John allen</a>"
#                     ],
#                     "photo_reference": "ATtYBwJJaNWgcFcVowBkC5XxfogesHCUwJ8D8_kqHPqLEunDOQ4Eyh9o99IinuJsG33xoe2a9vxEtnmgmZZtGClLaZ3LKAC1dyTRJ0LmEMOhsP1-7GnDs9WHaRdbzwaOuQ3efCZ4FJq19cXjAECOFh1urCwBzsOeDL83gP7OkJgD5f6ols_W",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJa_52_zMVkFQRIsX5KSvv41k",
#             "plus_code": {
#                 "compound_code": "JMCC+43 Seattle, WA, USA",
#                 "global_code": "84VVJMCC+43"
#             },
#             "price_level": 3,
#             "rating": 4.7,
#             "reference": "ChIJa_52_zMVkFQRIsX5KSvv41k",
#             "scope": "GOOGLE",
#             "types": [
#                 "shoe_store",
#                 "bicycle_store",
#                 "point_of_interest",
#                 "clothing_store",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 2182,
#             "vicinity": "222 Yale Avenue North, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6186545,
#                     "lng": -122.3307729
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6199468802915,
#                         "lng": -122.3293627697085
#                     },
#                     "southwest": {
#                         "lat": 47.6172489197085,
#                         "lng": -122.3320607302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Play It Again Sports & Ski",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3006,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103434568382305911708\">Karel Scott</a>"
#                     ],
#                     "photo_reference": "ATtYBwII954Wufmn2GtX8VBRkFIbFjWTWR6rDJLC1rBLIUjGJP7nCr0lBikWpBEKnFflEKfJuF1S0eya-NLbxfVBbcXIWj7tBR0p8jGCMgJzNtVLOnoszlmAKfmvBQT3DxSpKdRWWK7tON7junnB7rrrzJRK9BYtzh6CxT8I9p_tE2CzZO3p",
#                     "width": 5344
#                 }
#             ],
#             "place_id": "ChIJU5tNPjQVkFQRUDMcQiJNK9U",
#             "plus_code": {
#                 "compound_code": "JM99+FM Seattle, WA, USA",
#                 "global_code": "84VVJM99+FM"
#             },
#             "rating": 3.9,
#             "reference": "ChIJU5tNPjQVkFQRUDMcQiJNK9U",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 95,
#             "vicinity": "1304 Stewart Street, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6127018,
#                     "lng": -122.3186498
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6141720302915,
#                         "lng": -122.3173233697085
#                     },
#                     "southwest": {
#                         "lat": 47.6114740697085,
#                         "lng": -122.3200213302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "M\u00e9tier Seattle",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1667,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114827560965267810462\">M\u00e9tier Seattle</a>"
#                     ],
#                     "photo_reference": "ATtYBwKlyIfc7_8ncYg2B8Ge30onJXTw3AJTQptbc-_yNpGTwMAGlcdHsr-tdjdjSITdmd3lnt8ksUOCW_cOiaOkn5Onp-BEJmUsSTsdEefGzU51xckgvxQQw2V_4pXQnnnvKecMFM2GoUo55ppUXJExAf4f7rlzlvkrkAGqdiklVkZoPd0p",
#                     "width": 2500
#                 }
#             ],
#             "place_id": "ChIJsRdC0AcVkFQR-M_ZN_wWOgU",
#             "plus_code": {
#                 "compound_code": "JM7J+3G Seattle, WA, USA",
#                 "global_code": "84VVJM7J+3G"
#             },
#             "rating": 4.3,
#             "reference": "ChIJsRdC0AcVkFQR-M_ZN_wWOgU",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "health",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 81,
#             "vicinity": "1017 East Union Street, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.615078,
#                     "lng": -122.3278078
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6165025802915,
#                         "lng": -122.3264576197085
#                     },
#                     "southwest": {
#                         "lat": 47.6138046197085,
#                         "lng": -122.3291555802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Rapha Seattle",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1333,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100268104947182026510\">Josh Ross</a>"
#                     ],
#                     "photo_reference": "ATtYBwKtv_lnMCwmAGR7Yr0-xgbr85aB8sn56S1HPwVVpaLQ_29zpY8MesDR7PMDzplNBFfMnADxqdWnxQd_LsXTQJBPbcnV8Y8EvihtgmfnYT5HDlgABSDtpBL3-r1JbIm7ox_-XZihzBJvaAST1JczkVVlg7Bvg7jMeetBSNfyNZoEG-Oq",
#                     "width": 2000
#                 }
#             ],
#             "place_id": "ChIJD8j-K8tqkFQRxaf5FFiDUeg",
#             "plus_code": {
#                 "compound_code": "JM8C+2V Seattle, WA, USA",
#                 "global_code": "84VVJM8C+2V"
#             },
#             "rating": 4.7,
#             "reference": "ChIJD8j-K8tqkFQRxaf5FFiDUeg",
#             "scope": "GOOGLE",
#             "types": [
#                 "clothing_store",
#                 "cafe",
#                 "bicycle_store",
#                 "food",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 105,
#             "vicinity": "301 East Pine Street, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6159809,
#                     "lng": -122.3353362
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6173794802915,
#                         "lng": -122.3339319697085
#                     },
#                     "southwest": {
#                         "lat": 47.6146815197085,
#                         "lng": -122.3366299302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "MBR Bike Shop + Mobile Bicycle Rescue",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3672,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103645242770530988062\">Blair Daly</a>"
#                     ],
#                     "photo_reference": "ATtYBwKpP_7FugMXF8o7ZNjzi3U1HytU8DLFdssez9JwB6JuC2hOpObiIjk5qoezZhOVeZqF1PFFjHb71UlGsmWANdwUSUqp-aQQnwHz3d2Dn_nyELQDCpHo81itmHmTsF24KIYA19458TzDg7SI0_z8TmhdmxetEI1RVpWN6TEhlAVitdVp",
#                     "width": 7676
#                 }
#             ],
#             "place_id": "ChIJxx8siEoVkFQRf-LYmhygEug",
#             "plus_code": {
#                 "compound_code": "JM87+9V Seattle, WA, USA",
#                 "global_code": "84VVJM87+9V"
#             },
#             "rating": 4.2,
#             "reference": "ChIJxx8siEoVkFQRf-LYmhygEug",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 34,
#             "vicinity": "1961 9th Avenue, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6157017,
#                     "lng": -122.3408793
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6171177802915,
#                         "lng": -122.3394714197085
#                     },
#                     "southwest": {
#                         "lat": 47.6144198197085,
#                         "lng": -122.3421693802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Velo Bike Shop",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105746056324544705882\">Velo Bike Shop</a>"
#                     ],
#                     "photo_reference": "ATtYBwKAdFxNHqL_KXrFtovFKtwOQ0JUHL8qGX600PUOF73Gph3CdlDM8mH1Huf7UzIeW5D4VYb-13uj9Tut2_pkC-usQeiUP9AetFfNJszKcqX_SZdfvcj9bcM6wbhOA3jFgcMdD5VeF9aYL-ZaCYoOIwr1F3Y1ppY7p2If4fao-jNqDfbu",
#                     "width": 1504
#                 }
#             ],
#             "place_id": "ChIJKTKBss1qkFQR7soJvq6mDCg",
#             "plus_code": {
#                 "compound_code": "JM85+7J Seattle, WA, USA",
#                 "global_code": "84VVJM85+7J"
#             },
#             "rating": 4,
#             "reference": "ChIJKTKBss1qkFQR7soJvq6mDCg",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "parking",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 117,
#             "vicinity": "2151 6th Avenue, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.61374139999999,
#                     "lng": -122.3175796
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6148981802915,
#                         "lng": -122.3162434697085
#                     },
#                     "southwest": {
#                         "lat": 47.6122002197085,
#                         "lng": -122.3189414302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Good Weather Bicycle & Caf\u00e9",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104241906108733953361\">Good Weather Bicycle &amp; Caf\u00e9</a>"
#                     ],
#                     "photo_reference": "ATtYBwJ_QVc20ufwbrTzicFmPcag4P2th1RJt4cBXrbAZ7wnZYD6-9xh7mlH0wTn49XqhQg4Yz5buQDilsb3Ua-vCmu91nR717EvSJuaSVSlZqeYp8HzUwplmbSR6qs3FAwpXYzdK2sq28TJC3FXmvHxJUHYM4bs5ZPftjhRpH452uHPUU84",
#                     "width": 2000
#                 }
#             ],
#             "place_id": "ChIJ7b3xss1qkFQRESZrR5_st9Y",
#             "plus_code": {
#                 "compound_code": "JM7J+FX Seattle, WA, USA",
#                 "global_code": "84VVJM7J+FX"
#             },
#             "rating": 4.9,
#             "reference": "ChIJ7b3xss1qkFQRESZrR5_st9Y",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "cafe",
#                 "food",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 129,
#             "vicinity": "In the Alley, 1424 11th Avenue, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.5995842,
#                     "lng": -122.3337956
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6009344302915,
#                         "lng": -122.3326150197085
#                     },
#                     "southwest": {
#                         "lat": 47.5982364697085,
#                         "lng": -122.3353129802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "name": "Back Alley Bike Repair",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2161,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112059489151811791830\">Back Alley Bike Repair</a>"
#                     ],
#                     "photo_reference": "ATtYBwK_Lyo8aO9TArBAsfdeQOAPdLgdCEOyXcQk9D5H-dkRDihAFyw2V_VqGrkNFmJ_OuH_26sq5Fi6H8asFN25FRFOUN6ny1BBoDyAmhiPnKsssUdvzWO6q_PldxMkCz9HTr_4EBVaT3sVKptGy9QYKaGPoBq9i6-SbJlyZcx_uL70g04_",
#                     "width": 2161
#                 }
#             ],
#             "place_id": "ChIJ8TJK36RqkFQRkxFMSDYBHPA",
#             "plus_code": {
#                 "compound_code": "HMX8+RF Seattle, WA, USA",
#                 "global_code": "84VVHMX8+RF"
#             },
#             "rating": 4.7,
#             "reference": "ChIJ8TJK36RqkFQRkxFMSDYBHPA",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 62,
#             "vicinity": "314 1st Avenue South, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.5965672,
#                     "lng": -122.3334191
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.59791723029149,
#                         "lng": -122.3324318197085
#                     },
#                     "southwest": {
#                         "lat": 47.59521926970849,
#                         "lng": -122.3351297802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Swift Industries",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1536,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116235535720836120090\">Swift Industries</a>"
#                     ],
#                     "photo_reference": "ATtYBwIQrzds1uutWj5s2o8fMzckotlzcKRz6SWAF8ZaxD8nuGFqm70cjD1-8dUOLnDhMFV6rHzp9_aIq608WabjhlUQAv0uD69gZmgJ5ZzNlkiWSWr2FwnI2mrEEB7WWCv55GJcFVFYmp-mkU_4S7o6gDHFpU35dm0fcbi2xYU-BU90pbvi",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJ95o1mLcVkFQRcxbb56BamUg",
#             "plus_code": {
#                 "compound_code": "HMW8+JJ Seattle, WA, USA",
#                 "global_code": "84VVHMW8+JJ"
#             },
#             "rating": 4.5,
#             "reference": "ChIJ95o1mLcVkFQRcxbb56BamUg",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 21,
#             "vicinity": "558 1st Avenue South #200, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.61762049999999,
#                     "lng": -122.340374
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6186368302915,
#                         "lng": -122.3391729697085
#                     },
#                     "southwest": {
#                         "lat": 47.6159388697085,
#                         "lng": -122.3418709302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "VanMoof",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1200,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111639843461437587103\">VanMoof</a>"
#                     ],
#                     "photo_reference": "ATtYBwLqtpSy6Y6unxmVosXxlh2AbK8jH7l5wasMTCPVDXUaJxw8jhVCd_eSs7fPrn-0g4l-TI8UZqd9CD5gTAwFb8CIfXd-2qu66dL0rgdq4TmVq3ISKlFLdpVF243lfjHU0Jlvj0b86TioTg9lG10AzKji-i7DKyQ080SPYgdsk8kjYXdG",
#                     "width": 1600
#                 }
#             ],
#             "place_id": "ChIJQ9mAKG8VkFQRj053rjioJFM",
#             "plus_code": {
#                 "compound_code": "JM95+2V Seattle, WA, USA",
#                 "global_code": "84VVJM95+2V"
#             },
#             "rating": 5,
#             "reference": "ChIJQ9mAKG8VkFQRj053rjioJFM",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 14,
#             "vicinity": "2235 8th Avenue, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.5991599,
#                     "lng": -122.3084038
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.60055163029149,
#                         "lng": -122.3070555197085
#                     },
#                     "southwest": {
#                         "lat": 47.5978536697085,
#                         "lng": -122.3097534802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Dandelion Bikes",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118175699037232280803\">ProtonVehiCROSS</a>"
#                     ],
#                     "photo_reference": "ATtYBwJzjXs8Sm6w4no2V75HKkfc4q1HhS2SDkb6BsXVqfc4u1ZD3P1b68RNJ-ZHYGpkZsUrMWu5tEuadlLipubOuo2lHLLys2Njhhj8FoW80LoOXCqJGdVZ6POT0ZwIMraLaBHZvUJrfNVhYZ38lEJaH6YSzmD1su9bK-tMWkdC9r2RKbLs",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJKRX6W9prkFQRTqXdCD13hSQ",
#             "plus_code": {
#                 "compound_code": "HMXR+MJ Seattle, WA, USA",
#                 "global_code": "84VVHMXR+MJ"
#             },
#             "rating": 5,
#             "reference": "ChIJKRX6W9prkFQRTqXdCD13hSQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 8,
#             "vicinity": "1801 South Jackson Street #207, Seattle"
#         }
#     ],
#     "status": "OK"
# }

# %%
#Drill #3
#REI
#222 Yale Avenue North, Seattle

name = seattle_bikes_j['results'][0]['name']
print(name)
address = seattle_bikes_j['results'][0]['vicinity']
print(address)
# Out:
# REI
# 222 Yale Avenue North, Seattle

# %%
# 4. Find a balloon store near the White House.
target_search = "Balloon Store"
dc_coords = "38.8976763,-77.0365298"

# redefine params
params = {
    "location": dc_coords,
    "keyword": target_search,
    "radius": radius,
    "key": gkey
}

# Build URL using the Google Maps API
base_url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'

print("Drill #4: A Balloon Store Near the White House")

# Run request
dc_balloons = requests.get(base_url,params=params).json()

# Print the JSON (pretty printed)
print(json.dumps(dc_balloons, indent=4, sort_keys=True))
# Out:
# Drill #4: A Balloon Store Near the White House
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 38.8994447,
#                     "lng": -77.04019509999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.90069097989272,
#                         "lng": -77.03907507010727
#                     },
#                     "southwest": {
#                         "lat": 38.89799132010728,
#                         "lng": -77.04177472989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "BASHES.",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1440,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112969938165667888955\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwIr1pOZbglOPREWsCGRW4eUy3sKXtmxaq6LjkKqrbTcZYfD_Y1wuGUAy3jrEZNh90CnK9gGUHOMoN5N2afcEejHZK66FYjwiMNnWgZ9N_M_h3XKDv73KJBwdJNSfK8GfbNW4tB9Uavu_zTuxtt3K7vHiTSYf6j4XYuXCC6f6C0OmyI5",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJ2TzGbWG3t4kRTPyD2uRDtuo",
#             "plus_code": {
#                 "compound_code": "VXX5+QW Washington, District of Columbia",
#                 "global_code": "87C4VXX5+QW"
#             },
#             "rating": 5,
#             "reference": "ChIJ2TzGbWG3t4kRTPyD2uRDtuo",
#             "scope": "GOOGLE",
#             "types": [
#                 "home_goods_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "DELIVERY ONLY (NO PICK UP, 1717 Pennsylvania Avenue NW, Washington"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 38.8484985,
#                     "lng": -77.1233929
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.84973412989272,
#                         "lng": -77.12213512010727
#                     },
#                     "southwest": {
#                         "lat": 38.84703447010727,
#                         "lng": -77.12483477989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Party City",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2322,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117913403659594343780\">LUIS FIGUEROA</a>"
#                     ],
#                     "photo_reference": "ATtYBwLBWzc3C_R8i6vdeVDLLQtFMqMlUcsOmtain35uDecO5CUBv2YWT-OlGhRbmPWEdqYv7DOBLd8lWwynHBIcKhVRwJclwowmBCecqO-6si5c7Y6jqozdQccE0EIubJY8I-oXE_yTMlloBOAydbxLf-NZqdeCfElVbFxzez1AX-LYx10r",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJxaFOC_Ozt4kRthO-u4Mst8U",
#             "plus_code": {
#                 "compound_code": "RVXG+9J Falls Church, Virginia",
#                 "global_code": "87C4RVXG+9J"
#             },
#             "price_level": 2,
#             "rating": 3.8,
#             "reference": "ChIJxaFOC_Ozt4kRthO-u4Mst8U",
#             "scope": "GOOGLE",
#             "types": [
#                 "home_goods_store",
#                 "food",
#                 "point_of_interest",
#                 "clothing_store",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 476,
#             "vicinity": "5522 Leesburg Pike, Falls Church"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 38.846183,
#                     "lng": -77.094871
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.84771987989273,
#                         "lng": -77.09386177010728
#                     },
#                     "southwest": {
#                         "lat": 38.84502022010728,
#                         "lng": -77.09656142989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "My Custom Balloons",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 899,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108681319446564464525\">My Custom Balloons</a>"
#                     ],
#                     "photo_reference": "ATtYBwKCuzxOTG2LSrN2QVzDunj19MjKtfz5bdqjTj3Ao8_kSgHW6bwjJZOAT24PZiFlZA-4Zc-7PUuh0KFAPgB95AS3OTyhxAlTYjMVO3DasO6pkZIh7q3FKS8harOYaMdsVU8AHy3wG3N4X8EuFh00AeIJx-hHEYb-4861j29TvGWCeZcB",
#                     "width": 800
#                 }
#             ],
#             "place_id": "ChIJA0a9Jw-0t4kRRfvhsokIbus",
#             "plus_code": {
#                 "compound_code": "RWW4+F3 Arlington, Virginia",
#                 "global_code": "87C4RWW4+F3"
#             },
#             "rating": 5,
#             "reference": "ChIJA0a9Jw-0t4kRRfvhsokIbus",
#             "scope": "GOOGLE",
#             "types": [
#                 "home_goods_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 32,
#             "vicinity": "Next To BP Gas Station, 2305 S Walter Reed Dr Unit #6, Arlington"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 38.9291879,
#                     "lng": -77.03772479999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.93055862989272,
#                         "lng": -77.03628467010728
#                     },
#                     "southwest": {
#                         "lat": 38.92785897010727,
#                         "lng": -77.03898432989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Distributor El Savador",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "place_id": "ChIJa3Zo5yDIt4kRGN-9byp7QjU",
#             "plus_code": {
#                 "compound_code": "WXH6+MW Washington, District of Columbia",
#                 "global_code": "87C4WXH6+MW"
#             },
#             "rating": 2.8,
#             "reference": "ChIJa3Zo5yDIt4kRGN-9byp7QjU",
#             "scope": "GOOGLE",
#             "types": [
#                 "home_goods_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 4,
#             "vicinity": "3108 Mt Pleasant St NW, Washington"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 38.8482438,
#                     "lng": -77.1173712
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.84961767989272,
#                         "lng": -77.11616287010727
#                     },
#                     "southwest": {
#                         "lat": 38.84691802010727,
#                         "lng": -77.11886252989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Party Depot Bailey's Crossroad's (Curbside Pickup & Local Delivery Available)",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2268,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109458003192149806198\">Jos\u00e9 Ventura</a>"
#                     ],
#                     "photo_reference": "ATtYBwK7YXpNS8kZL5egL7gd3KwMhqKRvVYwc86MIhkjLTaqyDcger0pDmb2kofVI4yIYkp8vEgITBxSJFzdAu8vZoUYDAXRvZpnB7K9kLGzAEQdlL1CXQ_TPb21uRhp3STaYsaGDRhCtTfSIM7Fnz4KEPg6_6Yxpfw6sZkzqovySjzGJvbL",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJxzJXNPGzt4kRVkPv1lrHDdA",
#             "plus_code": {
#                 "compound_code": "RVXM+73 Falls Church, Virginia",
#                 "global_code": "87C4RVXM+73"
#             },
#             "rating": 3.3,
#             "reference": "ChIJxzJXNPGzt4kRVkPv1lrHDdA",
#             "scope": "GOOGLE",
#             "types": [
#                 "home_goods_store",
#                 "point_of_interest",
#                 "clothing_store",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 114,
#             "vicinity": "3513 S Jefferson St, Falls Church"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 38.8585569,
#                     "lng": -77.0503844
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.85958797989272,
#                         "lng": -77.04905402010728
#                     },
#                     "southwest": {
#                         "lat": 38.85688832010727,
#                         "lng": -77.05175367989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Total Party - Party, Costumes & Novelties",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 6000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109321737446037458760\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwKUXRkxNKDihDQCZxOAwC-op8GvSvGpFJP5fINJXn3NSMOUp794gqP0wMpF48N3MNYWqTVbpqNwq2y-cmrog0uiIaS0Sd3EQWmEC0p-wRkeblo0_5FgXGKNOCehcbQV-2b2j40EjDlcux-Kg-N2xPdCg0-4qwsbTUmmn4G4C8PmxXRN",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJ-57GR0m2t4kRnkc178_MdJc",
#             "plus_code": {
#                 "compound_code": "VW5X+CR Arlington, Virginia",
#                 "global_code": "87C4VW5X+CR"
#             },
#             "rating": 4.6,
#             "reference": "ChIJ-57GR0m2t4kRnkc178_MdJc",
#             "scope": "GOOGLE",
#             "types": [
#                 "home_goods_store",
#                 "point_of_interest",
#                 "clothing_store",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 50,
#             "vicinity": "Shops At 1750, 1663 Crystal Dr, Arlington"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 38.9047987,
#                     "lng": -77.0629668
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.90607947989272,
#                         "lng": -77.06153492010726
#                     },
#                     "southwest": {
#                         "lat": 38.90337982010728,
#                         "lng": -77.06423457989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Bizlinn Group, LLC",
#             "place_id": "ChIJReyLWpG3t4kRO3mB8r5mEZk",
#             "plus_code": {
#                 "compound_code": "WW3P+WR Washington, District of Columbia",
#                 "global_code": "87C4WW3P+WR"
#             },
#             "rating": 0,
#             "reference": "ChIJReyLWpG3t4kRO3mB8r5mEZk",
#             "scope": "GOOGLE",
#             "types": [
#                 "home_goods_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "1080 Wisconsin Ave NW APT 501, Washington"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 38.8855,
#                     "lng": -76.9963333
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.88684982989272,
#                         "lng": -76.99498347010729
#                     },
#                     "southwest": {
#                         "lat": 38.88415017010728,
#                         "lng": -76.99768312989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Groovy dc Cards & Gifts",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 640,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101396470284416050634\">D Dewayne</a>"
#                     ],
#                     "photo_reference": "ATtYBwLf5KrbQrxdijbYywEYiMypQ_I62ZGqXh4MJKtwLgFf7JueV9Vqw5Sw6-3ji5j6OhEuzLHHAYoJX9y3NU6t7M2fyDem9EAxZEXG84JWYXjdvRGiUY1yq2rCcQvU538lPIBvLSdXIgUmlg_j8bUlRsbiiMoTBOYh2LaV1WTiuKtOyydG",
#                     "width": 478
#                 }
#             ],
#             "place_id": "ChIJAQYWMTK4t4kRaC6Th7LSu8w",
#             "plus_code": {
#                 "compound_code": "V2P3+6F Washington, District of Columbia",
#                 "global_code": "87C5V2P3+6F"
#             },
#             "rating": 4.4,
#             "reference": "ChIJAQYWMTK4t4kRaC6Th7LSu8w",
#             "scope": "GOOGLE",
#             "types": [
#                 "home_goods_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 36,
#             "vicinity": "321 7th St SE, Washington"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 38.9003856,
#                     "lng": -76.9800988
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.90163452989272,
#                         "lng": -76.97881982010728
#                     },
#                     "southwest": {
#                         "lat": 38.89893487010728,
#                         "lng": -76.98151947989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Dollar Tree",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2576,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100513130410450865434\">dawnie ludwig</a>"
#                     ],
#                     "photo_reference": "ATtYBwIeRCD-0i7wtIieCUlvRB3TlTsbP36WyPjNnDkFgOSsAy5IiNMCm2_WJWtNORdVfZ7C-GqfLbJ0ZXWaYy62_wsX9mUcu7I8BQCN0wXxCsjy0gDuEm3W5EAbUtclv__G7Q94-aMHqRK5Cb4w4b0ZOi6XTPEyXt-ZWOfE_WP4hD7_pJo",
#                     "width": 1932
#                 }
#             ],
#             "place_id": "ChIJ82S_AUK4t4kR92_vNoU-V8w",
#             "plus_code": {
#                 "compound_code": "W229+5X Washington, District of Columbia",
#                 "global_code": "87C5W229+5X"
#             },
#             "price_level": 1,
#             "rating": 3.5,
#             "reference": "ChIJ82S_AUK4t4kR92_vNoU-V8w",
#             "scope": "GOOGLE",
#             "types": [
#                 "grocery_or_supermarket",
#                 "furniture_store",
#                 "home_goods_store",
#                 "food",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 301,
#             "vicinity": "1548 Benning Rd NE, Washington"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 38.9659979,
#                     "lng": -77.0278962
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.96734122989272,
#                         "lng": -77.02640522010728
#                     },
#                     "southwest": {
#                         "lat": 38.96464157010728,
#                         "lng": -77.02910487989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Balloons Raleigh",
#             "place_id": "ChIJVVUm9GHIt4kR_3njef8LX18",
#             "plus_code": {
#                 "compound_code": "XX8C+9R Washington, District of Columbia",
#                 "global_code": "87C4XX8C+9R"
#             },
#             "rating": 0,
#             "reference": "ChIJVVUm9GHIt4kR_3njef8LX18",
#             "scope": "GOOGLE",
#             "types": [
#                 "home_goods_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "6234 Georgia Ave NW, Washington"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 38.9454848,
#                     "lng": -76.9779571
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.94693642989272,
#                         "lng": -76.97629957010727
#                     },
#                     "southwest": {
#                         "lat": 38.94423677010728,
#                         "lng": -76.97899922989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Dollar Tree",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2576,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100513130410450865434\">dawnie ludwig</a>"
#                     ],
#                     "photo_reference": "ATtYBwKIOpl0NfQ2bXWXViHDR062TNEQnwfSl3Z6gOnhLXUWkmZwzQj-afUHD2D95Zk55lgUo4pigUSlLEb9VictZyF4KGy36Isp5IXiOV5IgN6q1jRL-nd-Yk0xz4_N5IyJl7BYlXbX6Rnasd9wBNYOspBbZikK7QJ-TM9_pMuWdVyrAPQ",
#                     "width": 1932
#                 }
#             ],
#             "place_id": "ChIJramYnLzHt4kRHpuakDrL3vM",
#             "plus_code": {
#                 "compound_code": "W2WC+5R Washington, District of Columbia",
#                 "global_code": "87C5W2WC+5R"
#             },
#             "price_level": 1,
#             "rating": 3.8,
#             "reference": "ChIJramYnLzHt4kRHpuakDrL3vM",
#             "scope": "GOOGLE",
#             "types": [
#                 "grocery_or_supermarket",
#                 "furniture_store",
#                 "home_goods_store",
#                 "food",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 471,
#             "vicinity": "1919 Michigan Ave NE, Washington"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 38.8586088,
#                     "lng": -77.0504941
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.85993037989272,
#                         "lng": -77.04917067010727
#                     },
#                     "southwest": {
#                         "lat": 38.85723072010727,
#                         "lng": -77.05187032989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Total Fright",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 6000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105640228281501439466\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwLAnIsHNW9yA1l9mX7G5ukNMDSEjP6MofP8dnEVY8iV3oEeX8a9LKrfO80-T_jEwpuYMCjxb3wvKz-tqT1hpvLByAvEDFxCIG0vdFDB2INYSgLpZWf2VEB_Zgt3VjVLs5UX7J5dvyOZapTG8i6jil9aRz9AZctp6W8bmd-ujq2IDekE",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJnZBiYSS0t4kRarOSCkTVaDg",
#             "plus_code": {
#                 "compound_code": "VW5X+CR Arlington, Virginia",
#                 "global_code": "87C4VW5X+CR"
#             },
#             "rating": 4.4,
#             "reference": "ChIJnZBiYSS0t4kRarOSCkTVaDg",
#             "scope": "GOOGLE",
#             "types": [
#                 "home_goods_store",
#                 "point_of_interest",
#                 "clothing_store",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 29,
#             "vicinity": "1750 Crystal Dr # D-40, Arlington"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 38.9083016,
#                     "lng": -77.03162689999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.90965142989273,
#                         "lng": -77.03044282010727
#                     },
#                     "southwest": {
#                         "lat": 38.90695177010728,
#                         "lng": -77.03314247989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Monarch Novelty Co",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108514088843488433198\">Marni Lenahan</a>"
#                     ],
#                     "photo_reference": "ATtYBwKIvPb1637t5Sg7nfRimyq5Eb9lLl5WuLRzBAp23fNPJhuGf8v3MzVX4wJ1wLDUulNFJpBq2qpQjzGnS7nPUiEF5eUDY4NEtX1a3g9IgHl7zCmz4S6zllbEb-JkbHViCzemLvrToyw8N2aBXLskD536FmZY9R_3kRss6rtPKJyXKxNP",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJ9Wbr9eq3t4kRYQHAG8-u7Yk",
#             "plus_code": {
#                 "compound_code": "WX59+88 Washington, District of Columbia",
#                 "global_code": "87C4WX59+88"
#             },
#             "rating": 3.6,
#             "reference": "ChIJ9Wbr9eq3t4kRYQHAG8-u7Yk",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 9,
#             "vicinity": "1331 14th St NW, Washington"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 38.9655822,
#                     "lng": -77.10660969999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.96715617989272,
#                         "lng": -77.10535767010727
#                     },
#                     "southwest": {
#                         "lat": 38.96445652010728,
#                         "lng": -77.10805732989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "BALLOON TO THE MOON",
#             "place_id": "ChIJ5YwtnijKt4kRJf3A5F4nyYU",
#             "plus_code": {
#                 "compound_code": "XV8V+69 Bethesda, Maryland",
#                 "global_code": "87C4XV8V+69"
#             },
#             "rating": 0,
#             "reference": "ChIJ5YwtnijKt4kRJf3A5F4nyYU",
#             "scope": "GOOGLE",
#             "types": [
#                 "store",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "5110 Ridgefield Rd #403, Bethesda"
#         }
#     ],
#     "status": "OK"
# }

# %%
# Print the name and address of the first balloon shop that appears
b_name = dc_balloons['results'][0]['name']
print(b_name)
b_addr = dc_balloons['results'][0]['vicinity']
print(b_addr)
# Out:
# BASHES.
# DELIVERY ONLY (NO PICK UP, 1717 Pennsylvania Avenue NW, Washington

# %%
# 5. Find the nearest dentist to your house.
# Hint: Use Google Maps to find your latitude and Google Places to find
# the dentist. You may also need the rankby property.

# Google geocode to find lat, lng
my_address = "151 Sip Ave"


params = {
    "address": my_address,
    "key": gkey
}

base_url = "https://maps.googleapis.com/maps/api/geocode/json"

print("Drill #5: A Dentist Near My House")

my_geo = requests.get(base_url, params).json()

lat = my_geo['results'][0]['geometry']['location']['lat']
lng = my_geo['results'][0]['geometry']['location']['lng']


# Use lat, lng to use places API to find nearest dentist
target_search = "dentist"

params = {
    "location": f"{lat},{lng}",
    "types": target_search,
    "rankby": "distance",
    "key": gkey
}

base_url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'


# Run request
response = requests.get(base_url,params=params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)
my_dentist = response.json()

# Print the JSON (pretty printed)
# print(json.dumps(my_dentist, indent=4, sort_keys=True))

# Print the name and address of the first dentist that appears
d_name = my_dentist['results'][0]['name']
print(d_name)
d_addr = my_dentist['results'][0]['vicinity']
print(d_addr)
# Out:
# Drill #5: A Dentist Near My House
# Popper Jason DDS
# 312 Academy Street # A, Jersey City

# %%
# 6. Bonus: Find the names and addresses of the top five restaurants in your home city.
#    Hint: Read about "Text Search Results"
# (https://developers.google.com/places/web-service/search#TextSearchRequests)
my_phrase = "best restaurant in Washington, DC"
target_url = "https://maps.googleapis.com/maps/api/place/textsearch/json"

params = {
    "query": my_phrase,
    "key": gkey
}

print("Drill #6: Bonus")
response = requests.get(target_url,params=params)
rest = response.json()
rest
# Out:
# Drill #6: Bonus
# {'html_attributions': [],
#  'next_page_token': 'ATtYBwIJKxh11BQCNBHXAeAk-tZUw2mZR8g_X1yrfS959tkcGc4c7-1sJxUQvmW2nrBok-zgsfxKkKb4H6Wa_H8k7z3UQaIEvBftjnYawzUujNXLXMSYK_5cKpRhCeRZqVwgsoh_oMce6OA-mbCYhgQBYhVRPE7TmEjy6MCiHIlDBU_itxERoSrnInJXqYGPbz4QtHSbF1OHpZR0JETp3LboQimU7KS46iMj88398QaMCUGmHs0QrftNc_QzpXZQvTK1A0I2ov21sSYCSZcb4qlYw__T6-5ZSYPWE-3z_IPi9fhlmz49K3sbxwK_fZcLZvGHIdMRT21zKTZyqFt3_2dQ1MQsk3QAfQvKlh2zGHsbVLJz1LsV-28Zk22PPN3OfcPbk9ndZLRG4Z00cBUet_dAlju9-gpRKtgy01IcWilHNw',
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': '1601 14th St NW, Washington, DC 20009, United States',
#    'geometry': {'location': {'lat': 38.911365, 'lng': -77.0316635},
#     'viewport': {'northeast': {'lat': 38.91262007989273,
#       'lng': -77.03045592010729},
#      'southwest': {'lat': 38.90992042010728, 'lng': -77.03315557989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Le Diplomate',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 512,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111960093028375434707">mis Mackenzie</a>'],
#      'photo_reference': 'ATtYBwKdIDmURz3OfviOMNSsGScQvmZ5cEbSi26RL5qBoxjTN9p3b7-i_-LO05HPDgAxg9kFgNJ_8vWoPBqZGy_xewe24YpPwSaVL-wOwYaiKZTgvTvJrYTly2kY58yCmN3S7ZBKWmplMEvfOw7QKfWM_dI0t84bGtYGy4thJj84SJ4JuLA',
#      'width': 768}],
#    'place_id': 'ChIJgYIki-m3t4kRZImvuN_pp9Q',
#    'plus_code': {'compound_code': 'WX69+G8 Washington, District of Columbia',
#     'global_code': '87C4WX69+G8'},
#    'price_level': 3,
#    'rating': 4.6,
#    'reference': 'ChIJgYIki-m3t4kRZImvuN_pp9Q',
#    'types': ['meal_takeaway',
#     'cafe',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 3887},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '122 Blagden Alley NW, Washington, DC 20001, United States',
#    'geometry': {'location': {'lat': 38.9063446, 'lng': -77.0245248},
#     'viewport': {'northeast': {'lat': 38.90767097989271,
#       'lng': -77.02324887010728},
#      'southwest': {'lat': 38.90497132010727, 'lng': -77.02594852989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'The Dabney',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107643839910081267145">Eva Yu</a>'],
#      'photo_reference': 'ATtYBwLsRpL-RC3ZP1Aaf4RUFnsS-EhT_ShGleqEwxhnOC7EtFJd_PxJyyVmne39oNG4Q4zcMftkSGx0s9J1xqjdsyuHppoiAqdxrB1P3wfVUkRYL4fGEONXnlgZ3mN0pfhnnR4FMJIvEMmJf5rz5EtmZzXL0cPKyLbsYgx0N6-TH3RR5Jw',
#      'width': 4032}],
#    'place_id': 'ChIJrTuAH-23t4kRUu2vghXPScI',
#    'plus_code': {'compound_code': 'WX4G+G5 Washington, District of Columbia',
#     'global_code': '87C4WX4G+G5'},
#    'price_level': 3,
#    'rating': 4.8,
#    'reference': 'ChIJrTuAH-23t4kRUu2vghXPScI',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 769},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '675 15th St NW, Washington, DC 20005, United States',
#    'geometry': {'location': {'lat': 38.897954, 'lng': -77.0333395},
#     'viewport': {'northeast': {'lat': 38.89934997989271,
#       'lng': -77.03216057010728},
#      'southwest': {'lat': 38.89665032010727, 'lng': -77.03486022989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Old Ebbitt Grill',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3717,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115849792569332703806">Old Ebbitt Grill</a>'],
#      'photo_reference': 'ATtYBwKs_TnwJGSjnYHqSnQAnQ-X_eFjSqPumr3dKCX6SxzQ5G9gjpzOYgUvfD0UV0a-pEymi1uoyihGZniwlVZIr-pwgCOJl_URMc8XENJ3BGXsu0RKjvi7kfNTGLro0CoxHzjt2QNCD4C-TTaeqqNdXv8AjPQhC3zMsZgEIcg3TJgQtzds',
#      'width': 5117}],
#    'place_id': 'ChIJgRwXf723t4kRdfqt36VafUU',
#    'plus_code': {'compound_code': 'VXX8+5M Washington, District of Columbia',
#     'global_code': '87C4VXX8+5M'},
#    'price_level': 2,
#    'rating': 4.6,
#    'reference': 'ChIJgRwXf723t4kRdfqt36VafUU',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 11296},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '701 9th St NW, Washington, DC 20001, United States',
#    'geometry': {'location': {'lat': 38.8987445, 'lng': -77.023684},
#     'viewport': {'northeast': {'lat': 38.89994492989272,
#       'lng': -77.02242367010729},
#      'southwest': {'lat': 38.89724527010728, 'lng': -77.02512332989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Zaytinya',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103511625562046742089">Twum Aning</a>'],
#      'photo_reference': 'ATtYBwL33JAsq1zI2NLS_f-O-8yBSGoPiadFeknaO2d4k7uPlc1P_HkW8kmaouBiE6Xi6GtX6Uvt0IcLIEQ0IBHIkMPKi6EN9hqNqR4uSZcnhgmHanCVEIRSjMpSCdl8Q9YEDzSvVdYJ8QAWoi-zOjDDTAUDMsDjVwaP2bRKMVmjMPboDlkn',
#      'width': 4032}],
#    'place_id': 'ChIJ3_mSkpG3t4kRDEWpol01OrI',
#    'plus_code': {'compound_code': 'VXXG+FG Washington, District of Columbia',
#     'global_code': '87C4VXXG+FG'},
#    'price_level': 3,
#    'rating': 4.5,
#    'reference': 'ChIJ3_mSkpG3t4kRDEWpol01OrI',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 4414},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '5100 MacArthur Blvd, Washington, DC 20016, United States',
#    'geometry': {'location': {'lat': 38.9249403, 'lng': -77.1017324},
#     'viewport': {'northeast': {'lat': 38.92631057989271,
#       'lng': -77.10028247010729},
#      'southwest': {'lat': 38.92361092010727, 'lng': -77.10298212989274}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Bistro Aracosia',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116102359324464490943">Collin McFarlane</a>'],
#      'photo_reference': 'ATtYBwKg0NJOOC2JrpyE9it2gJ8WrNTdGsusuH-4Q4pBy3JYLvrs4-FdksOqgiaiCZp7DFmnWp1ODUF37kw0BS3Denhby57qz0SeCiOUsB0aiBl15yYjSDNMWJPFAvCtKkuPTk7SIQ2-QrhHByLJTjE8FrB9a2tJoSAG6v1vljaSi_BnVd1d',
#      'width': 4032}],
#    'place_id': 'ChIJY0cU7Ae2t4kR1-im3ksVvIs',
#    'plus_code': {'compound_code': 'WVFX+X8 Washington, District of Columbia',
#     'global_code': '87C4WVFX+X8'},
#    'price_level': 2,
#    'rating': 4.9,
#    'reference': 'ChIJY0cU7Ae2t4kR1-im3ksVvIs',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 390},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '1346 Florida Ave NW, Washington, DC 20009, United States',
#    'geometry': {'location': {'lat': 38.9198048, 'lng': -77.0309984},
#     'viewport': {'northeast': {'lat': 38.92136777989272,
#       'lng': -77.02969812010728},
#      'southwest': {'lat': 38.91866812010728, 'lng': -77.03239777989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Maydan',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100974055513793874245">allison nielsen</a>'],
#      'photo_reference': 'ATtYBwIa1umq-GeF5HgVveV4DR83qjIQjEv2q1ZR-Mxg9UBQ7IqgWEslfq-Vj9HpvCgdD-rzEgUx7DLd4zGV9YbCunMWp5hUzTsgByzUmGmRiW962johLKpuh0H3prfBXiqetL_ZIdtcuW_ygAh75dRv-f-viW2tNOwcgGUfR37DyMUFQVYO',
#      'width': 3024}],
#    'place_id': 'ChIJuRQJIue3t4kR4aTvgqKSRg0',
#    'plus_code': {'compound_code': 'WX99+WJ Washington, District of Columbia',
#     'global_code': '87C4WX99+WJ'},
#    'price_level': 3,
#    'rating': 4.7,
#    'reference': 'ChIJuRQJIue3t4kR4aTvgqKSRg0',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 931},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '750 15th St NW, Washington, DC 20005, United States',
#    'geometry': {'location': {'lat': 38.89996, 'lng': -77.03393109999999},
#     'viewport': {'northeast': {'lat': 38.90143707989272,
#       'lng': -77.03244022010726},
#      'southwest': {'lat': 38.89873742010727, 'lng': -77.03513987989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': "Joe's Seafood, Prime Steak & Stone Crab",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107328781916981829355">Paul Newman</a>'],
#      'photo_reference': 'ATtYBwJSyBU2Q1CSAnNeVFxc4xmOc9mhTGd0WqCG4UFPVhpfNpFF_Ukvt1xPAYxgYn_VV13vXQRtk6dPGrY8U6fYU19GwmDymIwvX-71FfLXzk4UsFpU_MOvOdrtLcLYFKL-Ln3K5r9aFOnKbiAWtwcdH_YbdcamVs_c-5R8-zUmhGPTGwZG',
#      'width': 4032}],
#    'place_id': 'ChIJfYZV8r23t4kRrxfEzMf5GB8',
#    'plus_code': {'compound_code': 'VXX8+XC Washington, District of Columbia',
#     'global_code': '87C4VXX8+XC'},
#    'price_level': 3,
#    'rating': 4.7,
#    'reference': 'ChIJfYZV8r23t4kRrxfEzMf5GB8',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 3159},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '1340 4th St NE, Washington, DC 20002, United States',
#    'geometry': {'location': {'lat': 38.9097011, 'lng': -76.99921859999999},
#     'viewport': {'northeast': {'lat': 38.91096667989272,
#       'lng': -76.99767077010726},
#      'southwest': {'lat': 38.90826702010727, 'lng': -77.00037042989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Masseria',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3036,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112655524396635863518">Charlie Choe</a>'],
#      'photo_reference': 'ATtYBwJzvRILjBo8XsAOziOf04_u6dd1fD-r4gQfzmZfsxUcF9JdTs2EaYEUNkOq1Dh7O_i_B7ZFyl5C3rs1ZXsyMu5lIO6w1FbwiVz89_BpkGa4Q4wjxvwYfDzIy4PQip-3z3DJszGeT1iWpmXx5B5o_xkA4Rg-rvVVu2d671xvTJCV6Vy7',
#      'width': 4048}],
#    'place_id': 'ChIJp1AcfBq4t4kR8L1hnsBhxtE',
#    'plus_code': {'compound_code': 'W252+V8 Washington, District of Columbia',
#     'global_code': '87C5W252+V8'},
#    'price_level': 4,
#    'rating': 4.5,
#    'reference': 'ChIJp1AcfBq4t4kR8L1hnsBhxtE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 347},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '1015 7th St NW, Washington, DC 20001, United States',
#    'geometry': {'location': {'lat': 38.9035096, 'lng': -77.0216015},
#     'viewport': {'northeast': {'lat': 38.90486142989271,
#       'lng': -77.02041057010727},
#      'southwest': {'lat': 38.90216177010727, 'lng': -77.02311022989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Kinship',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114754422268523111116">Sharon Li</a>'],
#      'photo_reference': 'ATtYBwLvObK-gtdwW-7RieYMSdVmexbxUUSnqtvWtFd_MIox-TdwGXi1NarUNnsrTvcPx3N53cAAXvY8wBGa9Z7UM80GE6RzDSR7EZy4RbDEvIdnp35MquOdQVS-5apriTeKxXHFl-IEQCzR72rH6tSeCagj3JslFJDNy4XaNlCG9eaFOtnd',
#      'width': 2448}],
#    'place_id': 'ChIJRW5kXo23t4kRFG5VGwn1jUM',
#    'plus_code': {'compound_code': 'WX3H+C9 Washington, District of Columbia',
#     'global_code': '87C4WX3H+C9'},
#    'price_level': 4,
#    'rating': 4.7,
#    'reference': 'ChIJRW5kXo23t4kRFG5VGwn1jUM',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 568},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '724 9th St NW, Washington, DC 20001, United States',
#    'geometry': {'location': {'lat': 38.8991979, 'lng': -77.02418949999999},
#     'viewport': {'northeast': {'lat': 38.90053547989272,
#       'lng': -77.02272762010728},
#      'southwest': {'lat': 38.89783582010728, 'lng': -77.02542727989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Cranes',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3679,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116404538191383631222">A Google User</a>'],
#      'photo_reference': 'ATtYBwKsKw6fs6HaqaGBtR0PFgcONEhEvKyy41BXcwxd_q6Uluriu472RDUBqUBhJuxXLcGNpnI2TCKISwEjpicScHlcr30ULW7HeJyKIZyQEcOrZYdpOW30l_x031NlAr7_hD9TFYuWdfii_wtXeSe7TUruq3KlF5ZGXDNTuFoEb9VjKNZn',
#      'width': 5767}],
#    'place_id': 'ChIJ0Qfj-l-3t4kRGcx_Y4QZf6I',
#    'plus_code': {'compound_code': 'VXXG+M8 Washington, District of Columbia',
#     'global_code': '87C4VXXG+M8'},
#    'rating': 4.9,
#    'reference': 'ChIJ0Qfj-l-3t4kRGcx_Y4QZf6I',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 82},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '3462 14th St NW, Washington, DC 20010, United States',
#    'geometry': {'location': {'lat': 38.9329915, 'lng': -77.0329838},
#     'viewport': {'northeast': {'lat': 38.93429292989273,
#       'lng': -77.03151417010729},
#      'southwest': {'lat': 38.93159327010728, 'lng': -77.03421382989274}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Thip Khao Restaurant',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1836,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113649705611001558003">Qijun Tan</a>'],
#      'photo_reference': 'ATtYBwIyR8RZ67ghvwre0MT83wXz_gGSYXr0l3S4D8KJPjxQw7WmoyzaBWmQuwrHQihVwhALLUnMwnv-UzHD8fZtnP6wLsIf0KIjcFIbewpKzquIgz4jDBM907GokVlbRF6aBT3hpr5aXP6ECyrKjBH6hrviVbCmNjwd05mQRPjjc33JPEgA',
#      'width': 3264}],
#    'place_id': 'ChIJZ_aTmBjIt4kRBOOprOJHSwk',
#    'plus_code': {'compound_code': 'WXM8+5R Washington, District of Columbia',
#     'global_code': '87C4WXM8+5R'},
#    'price_level': 2,
#    'rating': 4.7,
#    'reference': 'ChIJZ_aTmBjIt4kRBOOprOJHSwk',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1008},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '717 8th St SE, Washington, DC 20003, United States',
#    'geometry': {'location': {'lat': 38.8806528, 'lng': -76.99514719999999},
#     'viewport': {'northeast': {'lat': 38.88199047989272,
#       'lng': -76.99371182010726},
#      'southwest': {'lat': 38.87929082010728, 'lng': -76.99641147989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': "Rose's Luxury",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 682,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110527212396830075435">Vidur Sirohi</a>'],
#      'photo_reference': 'ATtYBwL7keWhkOcMtR7CFZipzH4Uqf-JDzGZnU9TJ5C569oY4GIMfXwNNycaUkR7tRJ9XEF5uuYLdgVhMILvTxfj7ttLoZemJY4WhpXeKKOHo2ZfsG-bKcVyia6w8nL_VDLCU5eMW6tEzr4-MnXy8TvAG2M-tr3I2zxJWZ9MnJQradqgZt1i',
#      'width': 1024}],
#    'place_id': 'ChIJUZM20My5t4kRnhgopk_e4YA',
#    'plus_code': {'compound_code': 'V2J3+7W Washington, District of Columbia',
#     'global_code': '87C5V2J3+7W'},
#    'price_level': 3,
#    'rating': 4.7,
#    'reference': 'ChIJUZM20My5t4kRnhgopk_e4YA',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1090},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '2800 Pennsylvania Avenue NW, Washington, DC 20007, United States',
#    'geometry': {'location': {'lat': 38.904805, 'lng': -77.0572847},
#     'viewport': {'northeast': {'lat': 38.90614682989272,
#       'lng': -77.05585312010727},
#      'southwest': {'lat': 38.90344717010728, 'lng': -77.05855277989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'BOURBON STEAK',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108311402694021371728">Scott Ferrin</a>'],
#      'photo_reference': 'ATtYBwI5ePr7UWwydWWjd8e0ZrAFbBU244Zc9ky0BYmU70rD1fqoeKcjBNHDfm_jcAV74CYB45ex8OmZ-yBRNi4E4QkjbxdIviabGWQ3FvYcliTa1hUAXvF_P8BtP73nmPwBptW59sc7SGY6Td3khcyiv8hyuzpRlgD-1ocsWDam5_iheHdr',
#      'width': 3264}],
#    'place_id': 'ChIJNdBhOEu2t4kRiasAfqJKcvM',
#    'plus_code': {'compound_code': 'WW3V+W3 Washington, District of Columbia',
#     'global_code': '87C4WW3V+W3'},
#    'price_level': 4,
#    'rating': 4.5,
#    'reference': 'ChIJNdBhOEu2t4kRiasAfqJKcvM',
#    'types': ['night_club',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 444},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '974 Palmer Alley NW, Washington, DC 20001, United States',
#    'geometry': {'location': {'lat': 38.8999829, 'lng': -77.0257867},
#     'viewport': {'northeast': {'lat': 38.90124802989272,
#       'lng': -77.02447087010728},
#      'southwest': {'lat': 38.89854837010728, 'lng': -77.02717052989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Centrolina',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2395,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107019291940536952594">Steven Caudil</a>'],
#      'photo_reference': 'ATtYBwLujYSNFzzQ3STW-9jra7N76s00VRkYc0Na7CquPzPbO5cMOGlcWpn9tpNwSx-I9Bbk-taL4aoOvge_X8uXfFT52CujxqPKttMqnyV6ZIeZs7eC7aEWgTsKdmlOXzuOem9GLAvUonTUmfdiTz6-FbpJKlpDbSo_Boqh0i0JZcgmj6ux',
#      'width': 1908}],
#    'place_id': 'ChIJma782pO3t4kR-hKXI7SAq3U',
#    'plus_code': {'compound_code': 'VXXF+XM Washington, District of Columbia',
#     'global_code': '87C4VXXF+XM'},
#    'price_level': 3,
#    'rating': 4.4,
#    'reference': 'ChIJma782pO3t4kR-hKXI7SAq3U',
#    'types': ['grocery_or_supermarket',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 486},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '633 D St NW, Washington, DC 20004, United States',
#    'geometry': {'location': {'lat': 38.8949111, 'lng': -77.0212804},
#     'viewport': {'northeast': {'lat': 38.89620322989272,
#       'lng': -77.01993642010727},
#      'southwest': {'lat': 38.89350357010728, 'lng': -77.02263607989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Rasika',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105528261774243062418">Karna Sura</a>'],
#      'photo_reference': 'ATtYBwJRQlKe65J0fbpwCAvDycSRGrkGupj9OhN4Q4NLXxzy6Hku9-fomw2sp9fmPDYp0pmOynU-MafTQbu2zr2GF61zA3adUuR20eXagWvM7hXvpYDdrTq7t29tWMM3QIPBRF1SFBCjRB0wGuy9Ur4MCH6UJDiDmoWDpOeE-fvz3e7PL-P4',
#      'width': 3024}],
#    'place_id': 'ChIJJbjP-o-3t4kRpnr_gpNc4pE',
#    'plus_code': {'compound_code': 'VXVH+XF Washington, District of Columbia',
#     'global_code': '87C4VXVH+XF'},
#    'price_level': 3,
#    'rating': 4.4,
#    'reference': 'ChIJJbjP-o-3t4kRpnr_gpNc4pE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 2117},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '3226 11th St NW, Washington, DC 20010, United States',
#    'geometry': {'location': {'lat': 38.9302671, 'lng': -77.0280506},
#     'viewport': {'northeast': {'lat': 38.93157312989272,
#       'lng': -77.02668652010728},
#      'southwest': {'lat': 38.92887347010728, 'lng': -77.02938617989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Bad Saint',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103900351194661429459">Ken Yu</a>'],
#      'photo_reference': 'ATtYBwJPXS6YmmDrHFGXrmKtarbpAPtV46F6AHgsf-R_pttLGp76DXSoX80SCDDj35oase5lN9crvWFj4bdid4KN5rAVIITxIltia4as99t2x1FHz72WNbnoXv_m7Nj6QGxWNsU_Qy0z4LP_C16PIBik6WMXaguhoNYgaemN-FdOokOSCHpJ',
#      'width': 4032}],
#    'place_id': 'ChIJbdq0pR7It4kRIHzjG70zNNY',
#    'plus_code': {'compound_code': 'WXJC+4Q Washington, District of Columbia',
#     'global_code': '87C4WXJC+4Q'},
#    'price_level': 2,
#    'rating': 4.6,
#    'reference': 'ChIJbdq0pR7It4kRIHzjG70zNNY',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 473},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '601 Pennsylvania Avenue NW, Washington, DC 20004, United States',
#    'geometry': {'location': {'lat': 38.8935888, 'lng': -77.0203981},
#     'viewport': {'northeast': {'lat': 38.89460692989272,
#       'lng': -77.01892292010727},
#      'southwest': {'lat': 38.89190727010727, 'lng': -77.02162257989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'The Capital Grille',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101176987356509376734">The Capital Grille</a>'],
#      'photo_reference': 'ATtYBwKNrE3cAJK0y7V8FmWJJUmfGxQJjWSvy5OuF19hNAtDbrZximuz8CP7WWOKm4xgz2IEb72AEQ2gs671VtZuvyDqmZkwbvH8Ur5K08IFN76k2MHq35vYB3oKe2R_ZFY6qAyKPccICC15O3GvmfuI28r21AipTnGHya4i853fKkEGrAI-',
#      'width': 1000}],
#    'place_id': 'ChIJJT16aoW3t4kRqUrkWxGsAR8',
#    'plus_code': {'compound_code': 'VXVH+CR Washington, District of Columbia',
#     'global_code': '87C4VXVH+CR'},
#    'price_level': 4,
#    'rating': 4.6,
#    'reference': 'ChIJJT16aoW3t4kRqUrkWxGsAR8',
#    'types': ['meal_takeaway',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1509},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '1827 Adams Mill Rd NW, Washington, DC 20009, United States',
#    'geometry': {'location': {'lat': 38.92359769999999, 'lng': -77.0431323},
#     'viewport': {'northeast': {'lat': 38.92501567989272,
#       'lng': -77.04182057010728},
#      'southwest': {'lat': 38.92231602010727, 'lng': -77.04452022989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Tail Up Goat',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3036,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112485181411079593779">Lion L</a>'],
#      'photo_reference': 'ATtYBwI1NriJXLaNo4HhLQ6875AqpGj8HyMCrVghnpZtjKILP1tsuZzFasLPGz3LJxxj4u0bBAXulA7Ij-PywZrtQ8fXcioPoLJQsIlaTgI-FOwEte-so2xiEpySwv7ZcgQzGzv91UKOpkTZFxK2vcNpbzcCKkwR5wI0YTSvFwi_zEgOREd3',
#      'width': 3036}],
#    'place_id': 'ChIJgT2sldm3t4kRwS7hCfPYGCw',
#    'plus_code': {'compound_code': 'WXF4+CP Washington, District of Columbia',
#     'global_code': '87C4WXF4+CP'},
#    'price_level': 3,
#    'rating': 4.7,
#    'reference': 'ChIJgT2sldm3t4kRwS7hCfPYGCw',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 795},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '3100 K St NW, Washington, DC 20007, United States',
#    'geometry': {'location': {'lat': 38.9016959, 'lng': -77.060992},
#     'viewport': {'northeast': {'lat': 38.90313917989273,
#       'lng': -77.05972872010729},
#      'southwest': {'lat': 38.90043952010728, 'lng': -77.06242837989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Fiola Mare',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 6240,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105012534741572439125">Fiola Mare</a>'],
#      'photo_reference': 'ATtYBwKDHIvLmohphiealbct2pesPpxIYTzISOXRSc4HkvmnEX-Gch_ao-FGviXRFRkqoe0CdvQjKMnNBXhkvzql8eCXS9oPz5j55oEAPVQAOwZBj5UAOQlozva-GdT07voC8Mf0kHzJ-Qs9zdxRmKsNSF4yNELk84g4TIzkEQ3RMei2WVDp',
#      'width': 4160}],
#    'place_id': 'ChIJZUQ8NEy2t4kRX3b-nMqKZ-I',
#    'plus_code': {'compound_code': 'WW2Q+MJ Washington, District of Columbia',
#     'global_code': '87C4WW2Q+MJ'},
#    'price_level': 4,
#    'rating': 4.5,
#    'reference': 'ChIJZUQ8NEy2t4kRX3b-nMqKZ-I',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1198},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '2401 Pennsylvania Avenue NW, Washington, DC 20037, United States',
#    'geometry': {'location': {'lat': 38.9034757, 'lng': -77.0521854},
#     'viewport': {'northeast': {'lat': 38.90475502989273,
#       'lng': -77.05093652010729},
#      'southwest': {'lat': 38.90205537010728, 'lng': -77.05363617989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': "Marcel's by Robert Wiedmaier",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 801,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109719984750677722262">Asif Rahman</a>'],
#      'photo_reference': 'ATtYBwJ0QbhQMwP04dqpaqgjbGRzg986ymveRg1ilOJvPq-rP5P5jYA4hkmxUAZUTi8K0FHXReZHZmU2PofTMxjCEDYTqxuh8symm0pMFuvEjYtKeJIopY7A5PD8pAsDwXdFfzYgda_ldt9ZHtdVfyInQxsmkxEgmGIrofQI6QtPDv04Th0D',
#      'width': 1080}],
#    'place_id': 'ChIJox-jDbS3t4kRoc_gmS_tY7g',
#    'plus_code': {'compound_code': 'WW3X+94 Washington, District of Columbia',
#     'global_code': '87C4WW3X+94'},
#    'price_level': 4,
#    'rating': 4.6,
#    'reference': 'ChIJox-jDbS3t4kRoc_gmS_tY7g',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 283}],
#  'status': 'OK'}

# %%
cnt = 0
for r in rest['results']:
    print(r['name'])
    cnt+=1
    if cnt == 5:
        break
# Out:
# Le Diplomate
# The Dabney
# Old Ebbitt Grill
# Zaytinya
# Bistro Aracosia
