# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
manager_df = pd.read_csv("Salesmanager.csv")
manager_df.head()
# Out:
#    OrderDate   Region Sales Manager      Item  Units  Price
# 0   4-Jul-18     East          Mike  Notebook     62   4.99
# 1  12-Jul-18     East        Sophie    Binder     29   1.99
# 2  21-Jul-18  Central           Tom  Notebook     55  12.49
# 3  29-Jul-18     East          Anne    Binder     81  19.99
# 4   7-Aug-18  Central          Jack  Notebook     42  23.95

# %%
import pymongo
import csv
import json
from pymongo import MongoClient
client = MongoClient()
client = MongoClient('localhost', 27017)
db=client['sales']
colmanager=db['salesmanager']
colmanager.drop()

# %%
for index, row in manager_df.iterrows():
    print (row)
    colmanager.insert_one(row.to_dict())
# Out:
# OrderDate        4-Jul-18
# Region               East
# Sales Manager        Mike
# Item             Notebook
# Units                  62
# Price                4.99
# Name: 0, dtype: object
# OrderDate        12-Jul-18
# Region                East
# Sales Manager       Sophie
# Item                Binder
# Units                   29
# Price                 1.99
# Name: 1, dtype: object
# OrderDate        21-Jul-18
# Region             Central
# Sales Manager          Tom
# Item              Notebook
# Units                   55
# Price                12.49
# Name: 2, dtype: object
# OrderDate        29-Jul-18
# Region                East
# Sales Manager         Anne
# Item                Binder
# Units                   81
# Price                19.99
# Name: 3, dtype: object
# OrderDate        7-Aug-18
# Region            Central
# Sales Manager        Jack
# Item             Notebook
# Units                  42
# Price               23.95
# Name: 4, dtype: object
# ...

# %%
##colmanager.drop()
colmanager.insert_many(manager_df.to_dict('records'))

# %%
from config import cloudM ,cloudMpassword 
#print (cloudM,cloudMpassword)
cloudstr=f'mongodb+srv://{cloudM}:{cloudMpassword}@arinmongo-w3goy.mongodb.net/test?retryWrites=true&w=majority'
###
#using the example string above create your own connection string . 
#this is what you saved in the notepad during the cluster creation process

##
cloudclient = MongoClient(cloudstr)
#print(cloudstr)
colmanager.drop()
db=cloudclient['sales']
colmanager=db['salesmanager']
colmanager.insert_many(manager_df.to_dict('records'))

# %%
#db=cloudclient['sales']
#colmanager=db['salesmanager']

# %%
#colmanager.insert_many(manager_df.to_dict('records'))
