# %%
import pymongo
from pprint import pprint

# %%
connection_url = 'mongodb+srv://projectOlympics:project123@supriyada.h7evx.mongodb.net/myFirstDatabase?retryWrites=true&w=majority'
client = pymongo.MongoClient(connection_url)
Database = client.get_database('Olympics_Data_db')
# Table
dataTable = Database.athlete_record
logoTable = Database.logo_info

# %%
output = dataTable.aggregate([{
    '$match': {
        'Year': {'$eq': 1896},
        'Season': {'$eq': 'Summer'},
        'Medal':{'$ne': "None"}
    }
}, {
    '$group': {
        '_id':{'NOC':"$NOC", 'Medal':"$Medal"},
        'Medal_count': {'$sum': 1}
    }
},
    { '$unwind': "$_id" }
])

for r in output:
    
    print(r)
# Out:
# {'_id': {'NOC': 'AUS', 'Medal': 'Gold'}, 'Medal_count': 2}
# {'_id': {'NOC': 'GRE', 'Medal': 'Silver'}, 'Medal_count': 18}
# {'_id': {'NOC': 'FRA', 'Medal': 'Bronze'}, 'Medal_count': 2}
# {'_id': {'NOC': 'DEN', 'Medal': 'Silver'}, 'Medal_count': 2}
# {'_id': {'NOC': 'GER', 'Medal': 'Silver'}, 'Medal_count': 5}
# {'_id': {'NOC': 'AUT', 'Medal': 'Gold'}, 'Medal_count': 2}
# {'_id': {'NOC': 'GBR', 'Medal': 'Gold'}, 'Medal_count': 3}
# {'_id': {'NOC': 'AUT', 'Medal': 'Bronze'}, 'Medal_count': 2}
# {'_id': {'NOC': 'FRA', 'Medal': 'Silver'}, 'Medal_count': 4}
# {'_id': {'NOC': 'HUN', 'Medal': 'Bronze'}, 'Medal_count': 3}
# {'_id': {'NOC': 'DEN', 'Medal': 'Gold'}, 'Medal_count': 1}
# {'_id': {'NOC': 'GBR', 'Medal': 'Bronze'}, 'Medal_count': 3}
# {'_id': {'NOC': 'HUN', 'Medal': 'Gold'}, 'Medal_count': 2}
# {'_id': {'NOC': 'SUI', 'Medal': 'Silver'}, 'Medal_count': 2}
# {'_id': {'NOC': 'USA', 'Medal': 'Bronze'}, 'Medal_count': 2}
# {'_id': {'NOC': 'HUN', 'Medal': 'Silver'}, 'Medal_count': 1}
# {'_id': {'NOC': 'USA', 'Medal': 'Gold'}, 'Medal_count': 11}
# {'_id': {'NOC': 'GRE', 'Medal': 'Bronze'}, 'Medal_count': 20}
# {'_id': {'NOC': 'AUS', 'Medal': 'Bronze'}, 'Medal_count': 1}
# {'_id': {'NOC': 'USA', 'Medal': 'Silver'}, 'Medal_count': 7}
# {'_id': {'NOC': 'FRA', 'Medal': 'Gold'}, 'Medal_count': 5}
# {'_id': {'NOC': 'DEN', 'Medal': 'Bronze'}, 'Medal_count': 3}
# {'_id': {'NOC': 'GER', 'Medal': 'Gold'}, 'Medal_count': 25}
# {'_id': {'NOC': 'GRE', 'Medal': 'Gold'}, 'Medal_count': 10}
# {'_id': {'NOC': 'GBR', 'Medal': 'Silver'}, 'Medal_count': 3}
# {'_id': {'NOC': 'AUT', 'Medal': 'Silver'}, 'Medal_count': 1}
# {'_id': {'NOC': 'SUI', 'Medal': 'Gold'}, 'Medal_count': 1}
# {'_id': {'NOC': 'GER', 'Medal': 'Bronze'}, 'Medal_count': 2}

# %%
for r in output:
    print(r)

# %%
result = dataTable.aggregate([
  {"$group":{
    "_id":{"NOC":"$NOC","Medal":"$Medal"},
    "total_Medal":{"$sum":"$Medal"}
  }},
  {"$group":{
    "_id":"$_id.NOC",
    "v":{"$push":{"Medal":"$_id.Medal","Medal":"$Medal"}}
  }},
 {"$replaceRoot":{"newRoot":{
  "$let":{
    "vars":{"array":[{"k":"$_id", "v":"$v"}]},
    "in":{"$arrayToObject":"$$array"}}
 }}}
])

for r in result:
    print(r)
# Out:
# {'ISR': [{}, {}, {}, {}]}
# {'AHO': [{}, {}]}
# {'MON': [{}, {}]}
# {'TCH': [{}, {}, {}, {}]}
# {'GUI': [{}]}
# {'BIH': [{}]}
# {'LBR': [{}]}
# {'CRT': [{}]}
# {'SWZ': [{}]}
# {'STP': [{}]}
# {'MYA': [{}]}
# {'BOT': [{}, {}]}
# {'BLR': [{}, {}, {}, {}]}
# {'NRU': [{}]}
# {'MOZ': [{}, {}, {}]}
# {'KSA': [{}, {}, {}]}
# {'KIR': [{}]}
# {'VIE': [{}, {}, {}]}
# {'CHN': [{}, {}, {}, {}]}
# {'SVK': [{}, {}, {}, {}]}
# {'UZB': [{}, {}, {}, {}]}
# {'BDI': [{}, {}, {}]}
# {'SUD': [{}, {}]}
# {'IND': [{}, {}, {}, {}]}
# {'CAN': [{}, {}, {}, {}]}
# {'LES': [{}]}
# {'DEN': [{}, {}, {}, {}]}
# {'COK': [{}]}
# {'ANT': [{}]}
# {'ITA': [{}, {}, {}, {}]}
# {'GHA': [{}, {}, {}]}
# {'IRI': [{}, {}, {}, {}]}
# {'GUM': [{}]}
# {'AZE': [{}, {}, {}, {}]}
# {'KEN': [{}, {}, {}, {}]}
# {'MLT': [{}]}
# {'FIJ': [{}, {}]}
# {'YAR': [{}]}
# {'BEN': [{}]}
# {'CAF': [{}]}
# {'ROT': [{}]}
# {'SEY': [{}]}
# {'BAN': [{}]}
# {'LUX': [{}, {}, {}]}
# {'CRC': [{}, {}, {}, {}]}
# {'GEO': [{}, {}, {}, {}]}
# {'MEX': [{}, {}, {}, {}]}
# {'IRL': [{}, {}, {}, {}]}
# {'THA': [{}, {}, {}, {}]}
# {'IRQ': [{}, {}]}
# {'AFG': [{}, {}]}
# {'SOL': [{}]}
# {'ALG': [{}, {}, {}, {}]}
# {'NZL': [{}, {}, {}, {}]}
# {'UNK': [{}]}
# {'NFL': [{}]}
# {'ESA': [{}]}
# {'ARM': [{}, {}, {}, {}]}
# {'TAN': [{}, {}]}
# {'TLS': [{}]}
# {'FIN': [{}, {}, {}, {}]}
# {'LTU': [{}, {}, {}, {}]}
# {'BAR': [{}, {}]}
# {'RHO': [{}]}
# {'VEN': [{}, {}, {}, {}]}
# {'BUR': [{}]}
# {'VIN': [{}]}
# {'UAR': [{}, {}, {}]}
# {'KGZ': [{}, {}, {}]}
# {'PUR': [{}, {}, {}, {}]}
# {'PAN': [{}, {}, {}]}
# {'EST': [{}, {}, {}, {}]}
# {'URU': [{}, {}, {}, {}]}
# {'GRN': [{}, {}, {}]}
# {'WIF': [{}, {}]}
# {'GBS': [{}]}
# {'CAY': [{}]}
# {'NED': [{}, {}, {}, {}]}
# {'LIB': [{}, {}, {}]}
# {'SGP': [{}, {}, {}, {}]}
# {'FRA': [{}, {}, {}, {}]}
# {'GDR': [{}, {}, {}, {}]}
# {'GUY': [{}, {}]}
# {'NCA': [{}]}
# {'COL': [{}, {}, {}, {}]}
# {'ETH': [{}, {}, {}, {}]}
# {'ANZ': [{}, {}, {}, {}]}
# {'CRO': [{}, {}, {}, {}]}
# {'JPN': [{}, {}, {}, {}]}
# {'MAD': [{}]}
# {'HUN': [{}, {}, {}, {}]}
# {'NEP': [{}, {}]}
# {'VNM': [{}]}
# {'INA': [{}, {}, {}, {}]}
# {'RUS': [{}, {}, {}, {}]}
# {'PAR': [{}, {}]}
# {'GRE': [{}, {}, {}, {}]}
# {'HKG': [{}, {}, {}, {}]}
# {'CIV': [{}, {}, {}, {}]}
# {'PNG': [{}]}
# {'MNE': [{}, {}]}
# {'USA': [{}, {}, {}, {}]}
# {'SEN': [{}, {}]}
# {'BRN': [{}, {}, {}, {}]}
# {'KUW': [{}, {}]}
# {'CHI': [{}, {}, {}, {}]}
# {'HON': [{}]}
# {'MDA': [{}, {}, {}]}
# {'DJI': [{}, {}]}
# {'PER': [{}, {}, {}]}
# {'JAM': [{}, {}, {}, {}]}
# {'NAM': [{}, {}]}
# {'YEM': [{}]}
# {'NIG': [{}, {}, {}]}
# {'SOM': [{}]}
# {'LAO': [{}]}
# {'MAL': [{}]}
# {'AUT': [{}, {}, {}, {}]}
# {'SLE': [{}]}
# {'KAZ': [{}, {}, {}, {}]}
# {'CMR': [{}, {}, {}, {}]}
# {'SAM': [{}]}
# {'MAW': [{}]}
# {'SWE': [{}, {}, {}, {}]}
# {'NGR': [{}, {}, {}, {}]}
# {'RSA': [{}, {}, {}, {}]}
# {'GBR': [{}, {}, {}, {}]}
# {'TKM': [{}]}
# {'QAT': [{}, {}, {}]}
# {'MRI': [{}, {}]}
# {'PRK': [{}, {}, {}, {}]}
# {'CHA': [{}]}
# {'SUI': [{}, {}, {}, {}]}
# {'LCA': [{}]}
# {'COD': [{}]}
# {'SRI': [{}, {}]}
# {'BEL': [{}, {}, {}, {}]}
# {'ASA': [{}]}
# {'TPE': [{}, {}, {}, {}]}
# {'NOR': [{}, {}, {}, {}]}
# {'IOA': [{}, {}, {}, {}]}
# {'BUL': [{}, {}, {}, {}]}
# {'YUG': [{}, {}, {}, {}]}
# {'ALB': [{}]}
# {'JOR': [{}, {}]}
# {'SKN': [{}]}
# {'POL': [{}, {}, {}, {}]}
# {'LBA': [{}]}
# {'GUA': [{}, {}]}
# {'LIE': [{}, {}, {}, {}]}
# {'SMR': [{}]}
# {'ZAM': [{}, {}, {}]}
# {'FSM': [{}]}
# {'HAI': [{}, {}, {}, {}]}
# {'SYR': [{}, {}, {}, {}]}
# {'MTN': [{}]}
# {'PLW': [{}]}
# {'EUN': [{}, {}, {}, {}]}
# {'BHU': [{}]}
# {'TTO': [{}, {}, {}, {}]}
# {'TUN': [{}, {}, {}, {}]}
# {'PLE': [{}]}
# {'DMA': [{}]}
# {'RWA': [{}]}
# {'GER': [{}, {}, {}, {}]}
# {'MHL': [{}]}
# {'GAM': [{}]}
# {'ARG': [{}, {}, {}, {}]}
# {'AND': [{}]}
# {'GEQ': [{}]}
# {'ZIM': [{}, {}, {}, {}]}
# {'BRA': [{}, {}, {}, {}]}
# {'TOG': [{}, {}]}
# {'UKR': [{}, {}, {}, {}]}
# {'ANG': [{}]}
# {'SCG': [{}, {}, {}, {}]}
# {'BER': [{}, {}]}
# {'UAE': [{}, {}, {}]}
# {'MAS': [{}, {}, {}]}
# {'DOM': [{}, {}, {}, {}]}
# {'CPV': [{}]}
# {'URS': [{}, {}, {}, {}]}
# {'BAH': [{}, {}, {}, {}]}
# {'CZE': [{}, {}, {}, {}]}
# {'BRU': [{}]}
# {'GAB': [{}, {}]}
# {'SRB': [{}, {}, {}, {}]}
# {'POR': [{}, {}, {}, {}]}
# {'MAR': [{}, {}, {}, {}]}
# {'IVB': [{}]}
# {'PHI': [{}, {}, {}]}
# {'OMA': [{}]}
# {'EGY': [{}, {}, {}, {}]}
# {'BOH': [{}, {}, {}]}
# {'CUB': [{}, {}, {}, {}]}
# {'BOL': [{}]}
# {'AUS': [{}, {}, {}, {}]}
# {'BIZ': [{}]}
# {'ESP': [{}, {}, {}, {}]}
# {'PAK': [{}, {}, {}, {}]}
# {'CGO': [{}]}
# {'TJK': [{}, {}, {}, {}]}
# {'KOR': [{}, {}, {}, {}]}
# {'MGL': [{}, {}, {}, {}]}
# {'SAA': [{}]}
# {'TUV': [{}]}
# {'KOS': [{}, {}]}
# {'NBO': [{}]}
# {'ECU': [{}, {}, {}]}
# {'CYP': [{}, {}]}
# {'ERI': [{}, {}]}
# {'MKD': [{}, {}]}
# {'YMD': [{}]}
# {'SSD': [{}]}
# {'SUR': [{}, {}, {}]}
# {'LAT': [{}, {}, {}, {}]}
# {'ISL': [{}, {}, {}]}
# {'COM': [{}]}
# {'ROU': [{}, {}, {}, {}]}
# {'ISV': [{}, {}]}
# {'SLO': [{}, {}, {}, {}]}
# {'VAN': [{}]}
# {'FRG': [{}, {}, {}, {}]}
# {'CAM': [{}]}
# {'ARU': [{}]}
# {'MLI': [{}]}
# {'TUR': [{}, {}, {}, {}]}
# {'MDV': [{}]}
# {'UGA': [{}, {}, {}, {}]}
# {'TGA': [{}, {}]}
