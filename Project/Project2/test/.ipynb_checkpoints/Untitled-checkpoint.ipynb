# %%
from pymongo import MongoClient
import pymongo

# %%
conn_str=f'mongodb+srv://supriyaDA:Priya1008@supriyada.h7evx.mongodb.net/myFirstDatabase?retryWrites=true&w=majority'
client = pymongo.MongoClient(conn_str)

db = client["Olympics_Data_db"]
#collection = db.athlete_record
collection = db["noc_code"]

# %%
#not_found = []
#count = 0
for ncod in db.athlete_record.find(limit = 5):
    code = ncod['NOC']
    print(code)
#print("completed" + str(count))
# Out:
# CHN
# CHN
# DEN
# DEN
# NED

# %%
code_list = []
for row in db.noc_code.find():
    code = row['NOC']
    code_list.append(code)
print(code_list)
# Out:
# ['AFG', 'ALB', 'ALG', 'AND', 'ANG', 'ANT', 'ARG', 'ARM', 'ARU', 'ASA', 'AUS', 'AUT', 'AZE', 'BAH', 'BAN', 'BAR', 'BDI', 'BEL', 'BEN', 'BER', 'BHU', 'BIH', 'BIZ', 'BLR', 'BOL', 'BOT', 'BRA', 'BRN', 'BRU', 'BUL', 'BUR', 'CAF', 'CAM', 'CAN', 'CAY', 'CGO', 'CHA', 'CHI', 'CHN', 'CIV', 'CMR', 'COD', 'COK', 'COL', 'COM', 'CPV', 'CRC', 'CRO', 'CUB', 'CYP', 'CZE', 'DEN', 'DJI', 'DMA', 'DOM', 'ECU', 'EGY', 'ERI', 'ESA', 'ESP', 'EST', 'ETH', 'FIJ', 'FIN', 'FRA', 'FSM', 'GAB', 'GAM', 'GBR', 'GBS', 'GEO', 'GEQ', 'GER', 'GHA', 'GRE', 'GRN', 'GUA', 'GUI', 'GUM', 'GUY', 'HAI', 'HKG', 'HON', 'HUN', 'INA', 'IND', 'IRI', 'IRL', 'IRQ', 'ISL', 'ISR', 'ISV', 'ITA', 'IVB', 'JAM', 'JOR', 'JPN', 'KAZ', 'KEN', 'KGZ', 'KIR', 'KOR', 'KOS', 'KSA', 'KUW', 'LAO', 'LAT', 'LBA', 'LBN', 'LBR', 'LCA', 'LES', 'LIE', 'LTU', 'LUX', 'MAD', 'MAR', 'MAS', 'MAW', 'MDA', 'MDV', 'MEX', 'MGL', 'MHL', 'MKD', 'MLI', 'MLT', 'MNE', 'MON', 'MOZ', 'MRI', 'MTN', 'MYA', 'NAM', 'NCA', 'NED', 'NEP', 'NGR', 'NIG', 'NOR', 'NRU', 'NZL', 'OM
# ...

# %%
code_list=['YAR','YMD']
for code in code_list:
    country_name = db.noc_code.find_one({ "NOC": code })['CountryName']
    flag_url = db.noc_code.find_one({ "NOC": code })['FlagSrc']
    db.athlete_record.update_many({"NOC": code}, {'$set': {"Country": str(country_name),
                                                           "FlagSrc":flag_url}})

    print("completed" + code)
# Out:
# completedYAR
# completedYMD

# %%
code = "NFL"
#country_name = db.noc_code.find_one({ "NOC": code })['CountryName']
#flag_url = db.noc_code.find_one({ "NOC": code })['FlagSrc']
db.athlete_record.update_many({"NOC": code}, {'$set': {"Country": "Canada",
                                                       "FlagSrc":"None"}})

print("completed")
# Out:
# completed

# %%
country_name = db.noc_code.find_one({ "NOC": "AFG" })['CountryName']
print(country_name)
flag_url = db.noc_code.find_one({ "NOC": "AFG" })['FlagSrc']
print(flag_url)

# %%
r = db.athlete_record.find({"NOC":"MAR"})#.count()

for d in r:
    print(d)
print(r)
# Out:
# {'_id': ObjectId('60b4215bd1cc1ecb309bec71'), 'ID': 48, 'Name': 'Abdelhak Aatakni', 'Sex': 'M', 'Age': 24.0, 'Height': nan, 'Weight': 64.0, 'Team': 'Morocco', 'NOC': 'MAR', 'Games': '2012 Summer', 'Year': 2012, 'Season': 'Summer', 'City': 'London', 'Sport': 'Boxing', 'Event': "Boxing Men's Light-Welterweight", 'Medal': 'None', 'Country': 'Morocco', 'FlagSrc': '//upload.wikimedia.org/wikipedia/commons/thumb/2/2c/Flag_of_Morocco.svg/22px-Flag_of_Morocco.svg.png'}
# {'_id': ObjectId('60b4215bd1cc1ecb309bed0a'), 'ID': 154, 'Name': 'Khadija Abbouda', 'Sex': 'F', 'Age': 40.0, 'Height': 165.0, 'Weight': 57.0, 'Team': 'Morocco', 'NOC': 'MAR', 'Games': '2008 Summer', 'Year': 2008, 'Season': 'Summer', 'City': 'Beijing', 'Sport': 'Archery', 'Event': "Archery Women's Individual", 'Medal': 'None', 'Country': 'Morocco', 'FlagSrc': '//upload.wikimedia.org/wikipedia/commons/thumb/2/2c/Flag_of_Morocco.svg/22px-Flag_of_Morocco.svg.png'}
# ...

# %%
a = db.noc_code.find({"NOC": "YUG"})

for v in a:
    print(v)
# Out:
# {'_id': ObjectId('60bba3badcde5241b971e656'), 'NOC': 'YUG', 'FlagSrc': '//upload.wikimedia.org/wikipedia/commons/thumb/6/61/Flag_of_Yugoslavia_%281946-1992%29.svg/22px-Flag_of_Yugoslavia_%281946-1992%29.svg.png', 'CountryName': 'Yugoslavia'}

# %%
db.athlete_record.update_many({"NOC": "BOH"}, 
                              {'$set': {"Country": 'Bohemia',
                                        "FlagSrc": "//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Flag_of_Bohemia.svg/22px-Flag_of_Bohemia.svg.png"}})

# %%
code_list=['YUG','LIB','BOH','CRT','EUN','FRG','GDR','IOA','VNM','MAL','MKD','NBO','NFL','RHO','ROT','SAA','SCG','SWZ','TCH','UNK','WIF','YAR','YMD']

# %%
db.athlete_record.update_one({"NOC": "CHN"}, {'$set': {"Country": 'China'}})

# %%
db.noc_code.insert_one( { "NOC": "YUG", 
                         "FlagSrc": "//upload.wikimedia.org/wikipedia/commons/thumb/6/61/Flag_of_Yugoslavia_%281946-1992%29.svg/22px-Flag_of_Yugoslavia_%281946-1992%29.svg.png", 
                         "CountryName": "Yugoslavia" } );

# %%
db.noc_code.find({ "NOC": "URS" })

# %%
collection3 = db.Olympic_data_complete
for row in result:
    collection3.insert_one(row)
    
    
    result = db.athlete_record.aggregate([
   {
     '$lookup':
       {
         'from': "db.noc_code",
         'localField': "NOC",
         'foreignField': "NOC",
         'as': "details"
       }
  },
  { '$unwind': "$details" },
  {
    '$project': {
        "ID": 1,
        "Name": 1,
        "Sex": 1,
        "Age": 1,
        "Team": 1,
        "Height": 1,
        "Weight":1,
        "NOC": 1,
        "Games":1,
        "Year": 1,
        "Season": 1,
        "City": 1,
        "Sport": 1,
        "Event":1,
        "Medal": 1,
        "Flag": "$details.FlagSrc",
        "CountryName": "$details.CountryName"
        
    }    
  }
])

for r in result:
    print(r)
